# %% [markdown]
#     The best solution has fitness -4.0, and its Adam = B, Ben = D, Chloe = B, Daniel = B, Ethan = C, Felix = A, Grace = A, Hannah = B, Isaac = A, James = A, Katy = C, Leo = A, Mike = A, Noah = A, Olivia = B, Peter = A, Quinn = B, Riley = A
# For task 1
# With modification [('Isaac', 'B'), ('Olivia', 'A')], the fitness is -4.0
# With modification [('Isaac', 'B')], the fitness is -12.0
# With modification [('Adam', 'A')], the fitness is -20.0
# With modification [('Adam', 'A'), ('Isaac', 'B')], the fitness is -28.0
#
#
#
# The best solution has fitness -4.0, and its Alice = C, Brandon = C, Clara = C, Dominic = B, Eleanor = B, Fiona = D, Gabriel = C, Hazel = B, Ivy = A, Joshua = A, Kevin = D, Lucas = C, Matilda = B, Nathan = B, Oscar = A, Phoebe = D, Quentin = D, Rose = A
#
# For task 2
# With modification [('Brandon', 'D'), ('Kevin', 'C')], the fitness is -4.0
# With modification [('Alice', 'D'), ('Phoebe', 'C')], the fitness is -12.0
# With modification [('Lucas', 'D'), ('Phoebe', 'C')], the fitness is -12.0
# With modification [('Alice', 'D'), ('Lucas', 'D')], the fitness is -20.0
# With modification [('Alice', 'D'), ('Brandon', 'D')], the fitness is -20.0
# With modification [('Alice', 'D'), ('Kevin', 'C')], the fitness is -20.0
# With modification [('Lucas', 'D'), ('Brandon', 'D')], the fitness is -20.0
# With modification [('Lucas', 'D'), ('Kevin', 'C')], the fitness is -20.0
# With modification [('Phoebe', 'C'), ('Brandon', 'D')], the fitness is -28.0
# With modification [('Phoebe', 'C'), ('Kevin', 'C')], the fitness is -28.0

# %%
task_1_answers = {  'Put Isaac on B and Olivia on A': 4,
                    'Put Isaac on B': 12,
                    'Put Adam on A': 20,
                    'Put Adam on A and Isaac on B': 28}

task_2_answers_original = {'Brandon to D;Kevin to C':4,
                  'Alice to D;Phoebe to C':12,
                  'Lucas to D;Phoebe to C':12,
                  'Alice to D;Lucas to D':20,
                  'Alice to D;Brandon to D':20,
                  'Alice to D;Kevin to C':20,
                  'Brandon to D;Lucas to D':20,
                  'Kevin to C;Lucas to D':20,
                  'Brandon to D;Phoebe to C':28,
                  'Kevin to C;Phoebe to C':28,
}

task_2_answers = {'Brandon to D;Kevin to C':0,
                  'Alice to D;Phoebe to C':1,
                  'Lucas to D;Phoebe to C':1,
                  'Alice to D;Lucas to D':2,
                  'Alice to D;Brandon to D':2,
                  'Alice to D;Kevin to C':2,
                  'Brandon to D;Lucas to D':2,
                  'Kevin to C;Lucas to D':2,
                  'Brandon to D;Phoebe to C':3,
                  'Kevin to C;Phoebe to C':3,
}


def get_scores_for_task_1(task_1_answer: str): 
    items = task_1_answer.split(";")
    assert(all(item in task_1_answers for item in items))
    return [task_1_answer[item] for item in items]

def get_score_for_task_2(task_2_answer: str):
    actual_key = task_2_answer
    if actual_key not in task_2_answers:
        actual_key = ";".join(reversed(actual_key.split(";")))
    if actual_key not in task_2_answers:
        raise Exception(f"The key {task_2_answer} is not recognised")
    
    return task_2_answers[actual_key]

# %%
import pandas as pd


data_path = r"C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\UserStudy\data\answers_04_02.tsv"

def get_task_data(exclude_bad_users: bool):
    df = pd.read_csv(data_path, sep="\t")
    if exclude_bad_users:
        df = df[df["Good user?"] == True] 
    df = df[["Which form?", "Task 1 arrangement", "Task 2 tickboxes"]]
    
    return df.rename(columns={"Which form?":"Group", "Task 1 arrangement":"Task 1", "Task 2 tickboxes": "Task 2"})
    

display(get_task_data(exclude_bad_users=False))
display(get_task_data(exclude_bad_users=True))


def get_all_data(exclude_bad_users: bool):
    df = pd.read_csv(data_path, sep="\t")
    if exclude_bad_users:
        df = df[df["Good user?"] == True] 
    return df


display(get_all_data(exclude_bad_users=True))
# Out:
#    Group                                             Task 1  \
# 0      A  Put Adam on A and Isaac on B;Put Isaac B on an...
# 1      A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 2      A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 3      A  Put Isaac on B;Put Adam on A;Put Isaac on B an...
# 4      A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 5      A  Put Adam on A;Put Isaac on B and Olivia on A;P...
# 6      A  Put Isaac on B and Olivia on A;Put Adam on A;P...
# 7      A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 8      B  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 9      B  Put Adam on A;Put Isaac on B;Put Adam on A and...
# 10     B  Put Adam on A and Isaac on B;Put Isaac on B an...
# 11     B  Put Isaac on B;Put Adam on A and Isaac on B;Pu...
# 12     B  Put Adam on A and Isaac on B;Put Adam on A;Put...
# 13     B  Put Adam on A and Isaac on B;Put Adam on A;Put...
#
#                       Task 2
# 0    Kevin to C;Brandon to D
# 1    Brandon to D;Kevin to C
# 2    Brandon to D;Kevin to C
# 3   Phoebe to C;Brandon to D
# 4    Brandon to D;Kevin to C
# 5    Brandon to D;Kevin to C
# 6     Alice to D;Phoebe to C
# 7    Brandon to D;Kevin to C
# 8    Brandon to D;Kevin to C
# 9      Kevin to C;Alice to D
# 10   Brandon to D;Lucas to D
# 11     Lucas to D;Alice to D
# 12  Phoebe to C;Brandon to D
# 13     Lucas to D;Alice to D
#   Group                                             Task 1  \
# 0     A  Put Adam on A and Isaac on B;Put Isaac B on an...
# 1     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 2     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 3     A  Put Isaac on B;Put Adam on A;Put Isaac on B an...
# 4     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 6     A  Put Isaac on B and Olivia on A;Put Adam on A;P...
# 7     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 8     B  Put Isaac on B and Olivia on A;Put Isaac on B;...
#
#                      Task 2
# 0   Kevin to C;Brandon to D
# 1   Brandon to D;Kevin to C
# 2   Brandon to D;Kevin to C
# 3  Phoebe to C;Brandon to D
# 4   Brandon to D;Kevin to C
# 6    Alice to D;Phoebe to C
# 7   Brandon to D;Kevin to C
# 8   Brandon to D;Kevin to C
#    paid? Which form?  Id           Start time      Completion time  \
# 0   True           A   2  28/02/2025 15:15:00  28/02/2025 16:02:00
# 1   True           A   3  11/03/2025 11:13:00  11/03/2025 12:08:00
# 2   True           A   4  12/03/2025 12:47:00  12/03/2025 13:11:00
# 3   True           A   5  21/03/2025 02:12:00  21/03/2025 02:40:00
# 4   True           A   6  21/03/2025 10:12:00  21/03/2025 10:49:00
# 6   True           A   8  24/03/2025 16:26:00  24/03/2025 16:56:00
# 7   True           A   9  31/03/2025 10:26:00  31/03/2025 11:03:00
# 8   True           B   2  28/02/2025 15:10:00  28/02/2025 15:54:00
#
#   Account email  Name Eligible consent                         email  ...  \
# 0     anonymous   NaN      Yes     Yes  jld00020@students.stir.ac.uk  ...
# 1     anonymous   NaN      Yes     Yes  sia00085@students.stir.ac.uk  ...
# 2     anonymous   NaN      Yes     Yes  gkz00001@students.stir.ac.uk  ...
# 3     anonymous   NaN      Yes     Yes  rjh00038@students.stir.ac.uk  ...
# 4     anonymous   NaN      Yes     Yes  amt00112@students.stir.ac.uk  ...
# 6     anonymous   NaN      Yes     Yes  omi00021@students.stir.ac.uk  ...
# 7     anonymous   NaN      Yes     Yes  bbh00001@students.stir.ac.uk  ...
# 8     anonymous   NaN      Yes     Yes  ell00088@students.stir.ac.uk  ...
#
#   Task 2 confidence in choice Task 2 I have reasons  \
# 0                       Agree                 Agree
# 1                       Agree                 Agree
# 2                       Agree                 Agree
# 3                       Agree                 Agree
# 4              Strongly Agree        Strongly Agree
# 6                     Neutral                 Agree
# 7              Strongly Agree        Strongly Agree
# 8                     Neutral               Neutral
#
#   Task 2 confidence in textual explanation Task 2 explanations were helpful  \
# 0                                  Neutral                                A
# 1                       Somewhat confident                                A
# 2                  Extremely not confident                                A
# 3                       Somewhat confident                                A
# 4                       Somewhat confident                                A
# 6                       Somewhat confident                                A
# 7                           Very confident                                A
# 8                                  Neutral                            Agree
#
#   Task 2 explanations easy to understand Task 2 explanations were accurate  \
# 0                                      A                                 A
# 1                                      A                                 A
# 2                                      A                                 A
# 3                                      A                                 A
# 4                                      A                                 A
# 6                                      A                                 A
# 7                                      A                                 A
# 8                               Disagree                             Agree
#
#   Task 2 explanations made me trust  \
# 0                                 A
# 1                                 A
# 2                                 A
# 3                                 A
# 4                                 A
# 6                                 A
# 7                                 A
# 8                           Neutral
#
#                      Task 2 more feedback about task               TotalTime  \
# 0                                                NaN  0 hours and 47 minutes
# 1                                                NaN  0 hours and 55 minutes
# 2  im not sure if any of my answers made sense, m...  0 hours and 24 minutes
# 3                                                NaN  0 hours and 28 minutes
# 4  Without the limitation all of the workers desi...  0 hours and 37 minutes
# 6  It explains the bit I was referring to in my l...  0 hours and 30 minutes
# 7                                                NaN  0 hours and 37 minutes
# 8                                                NaN  0 hours and 44 minutes
#
#   Good user?
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 6       True
# 7       True
# 8       True
#
# [8 rows x 56 columns]

# %% [markdown]
# # Code Description
# * Distance Calculation:
#   The code computes the distance between each participant's ranking and the ground truth using the Spearman footrule metric. This metric sums the absolute differences in positions for each item in the ranking compared to its position in the ground truth.
#
# * Statistical Testing:
#   Two statistical tests are carried out on the computed distances:
#
#     * Independent Samples t-test:
#     This test compares the mean distances between the two groups (X and Y) assuming normally distributed data.
#     * Mann-Whitney U Test:
#     A non-parametric alternative that does not assume normality, used to assess if one group tends to have lower distances (i.e., is closer to the ground truth) than the other.

# %%
import utils
from scipy.stats import ttest_ind, mannwhitneyu

# Define the ground truth ranking and create a lookup for item positions.
ground_truth = list(task_1_answers.items())
ground_truth.sort(key=utils.second)
ground_truth = [item for item, value in ground_truth]
ground_truth_index = {item: idx for idx, item in enumerate(ground_truth)}

print("The ground truth is")
for option, ranking in ground_truth_index.items():
    print(f"{option = }, {ranking = }")

def compute_distance(ranking_str, ground_truth_index):
    """
    Computes the Spearman footrule distance between a given ranking (as a semicolon-separated string)
    and the ground truth. It sums the absolute differences in positions for each item.
    """
    # Split the string into a list of items.
    ranking = ranking_str.split(";")
    distance = 0
    for i, item in enumerate(ranking):
        if item in ground_truth_index:
            distance += abs(i - ground_truth_index[item])
        else:
            print(f"Warning: {item} not in ground truth.")
    return distance

df = get_task_data(exclude_bad_users=True)

# Compute the distance for each participant.
df['Distance'] = df['Task 1'].apply(lambda x: compute_distance(x, ground_truth_index))
print("Data with computed distances:")
print(df[["Group", "Task 1", "Distance"]])

# Separate the distances by group.
group_a = df[df['Group'] == "A"]['Distance']
group_b = df[df['Group'] == "B"]['Distance']

# Perform an independent samples t-test.
t_stat, p_val = ttest_ind(group_a, group_b, equal_var=False, alternative = "less")
print("\nT-test results:")
print(f"t-statistic = {t_stat:.3f}, p-value = {p_val:.3f}")

# Perform a Mann-Whitney U test.
u_stat, p_val_mw = mannwhitneyu(group_a, group_b, alternative='less')
print("\nMann-Whitney U test results:")
print(f"U statistic = {u_stat:.3f}, p-value = {p_val_mw:.3f}")

# find the average of the groups
print(f"The average for group A is {group_a.mean()}")
print(f"The average for group B is {group_b.mean()}")

display(group_a)
display(group_b)
# Out:
# The ground truth is
# option = 'Put Isaac on B and Olivia on A', ranking = 0
# option = 'Put Isaac on B', ranking = 1
# option = 'Put Adam on A', ranking = 2
# option = 'Put Adam on A and Isaac on B', ranking = 3
# Warning: Put Isaac B on and Olivia on A not in ground truth.
# Data with computed distances:
#   Group                                             Task 1  Distance
# 0     A  Put Adam on A and Isaac on B;Put Isaac B on an...         5
# 1     A  Put Isaac on B and Olivia on A;Put Isaac on B;...         0
# 2     A  Put Isaac on B and Olivia on A;Put Isaac on B;...         0
# 3     A  Put Isaac on B;Put Adam on A;Put Isaac on B an...         4
# 4     A  Put Isaac on B and Olivia on A;Put Isaac on B;...         0
# 6     A  Put Isaac on B and Olivia on A;Put Adam on A;P...         2
# 7     A  Put Isaac on B and Olivia on A;Put Isaac on B;...         0
# 8     B  Put Isaac on B and Olivia on A;Put Isaac on B;...         2
#
# T-test results:
# t-statistic = nan, p-value = nan
#
# Mann-Whitney U test results:
# U statistic = 2.500, p-value = 0.407
# The average for group A is 1.5714285714285714
# The average for group B is 2.0
# C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\venv\lib\site-packages\scipy\stats\_stats_py.py:1113: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\venv\lib\site-packages\scipy\stats\_stats_py.py:1113: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# 0    5
# 1    0
# 2    0
# 3    4
# 4    0
# 6    2
# 7    0
# Name: Distance, dtype: int64
# 8    2
# Name: Distance, dtype: int64

# %% [markdown]
# # Code Description
# * Score Mapping:
#   The code maps each user's answer in the "Task 2" column to a corresponding score using the task_2_answers dictionary.
#
# * Group Comparison:
#   The resulting scores are separated by the "Group" column (with groups "X" and "Y").
#
# * Statistical Testing:
#   Two tests are performed to compare the scores between the groups:
#
#     * Independent Samples t-test:
#       This test compares the mean scores of the two groups.
#     * Mann-Whitney U Test:
#       A non-parametric test that assesses whether the distributions of scores differ significantly between the groups.

# %%
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu

df = get_task_data(exclude_bad_users=True).copy()

# Map each answer to its corresponding score.
df['Score'] = df['Task 2'].map(get_score_for_task_2)

display(df)

# Split the scores by group.
group_a_scores = df[df['Group'] == 'A']['Score']
group_b_scores = df[df['Group'] == 'B']['Score']

# Perform an independent samples t-test.
t_stat, p_val = ttest_ind(group_a_scores, group_b_scores, equal_var=False, alternative = "greater")
print("T-test results:")
print(f"t-statistic: {t_stat:.3f}, p-value: {p_val:.3f}")

# Perform a Mann-Whitney U test.
u_stat, p_val_mw = mannwhitneyu(group_a_scores, group_b_scores, alternative='greater')
print("\nMann-Whitney U test results:")
print(f"U statistic: {u_stat:.3f}, p-value: {p_val_mw:.3f}")

# show the means of the groups
print(f"The mean of the group A is {group_a_scores.mean()}")
print(f"The mean of the group B is {group_b_scores.mean()}")

display(group_a_scores)
display(group_b_scores)
# Out:
#   Group                                             Task 1  \
# 0     A  Put Adam on A and Isaac on B;Put Isaac B on an...
# 1     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 2     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 3     A  Put Isaac on B;Put Adam on A;Put Isaac on B an...
# 4     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 6     A  Put Isaac on B and Olivia on A;Put Adam on A;P...
# 7     A  Put Isaac on B and Olivia on A;Put Isaac on B;...
# 8     B  Put Isaac on B and Olivia on A;Put Isaac on B;...
#
#                      Task 2  Score
# 0   Kevin to C;Brandon to D      0
# 1   Brandon to D;Kevin to C      0
# 2   Brandon to D;Kevin to C      0
# 3  Phoebe to C;Brandon to D      3
# 4   Brandon to D;Kevin to C      0
# 6    Alice to D;Phoebe to C      1
# 7   Brandon to D;Kevin to C      0
# 8   Brandon to D;Kevin to C      0
# T-test results:
# t-statistic: nan, p-value: nan
#
# Mann-Whitney U test results:
# U statistic: 4.500, p-value: 0.388
# The mean of the group A is 0.5714285714285714
# The mean of the group B is 0.0
# C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\venv\lib\site-packages\scipy\stats\_stats_py.py:1113: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\venv\lib\site-packages\scipy\stats\_stats_py.py:1113: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# 0    0
# 1    0
# 2    0
# 3    3
# 4    0
# 6    1
# 7    0
# Name: Score, dtype: int64
# 8    0
# Name: Score, dtype: int64

# %%
import os

# then I would like to compare the answers between the groups for the subjective aspects


subjective_questions = ['Numeracy', 'Problem solving', 'Algorithmic thinking', 
                        
                        'Confident in using technology', 'Technology is useful', 'Technology is overrated', 'Let technology decide for me', 'Let technology decide my career', 'Let technology diagnose me', 
                        
                        #'Familiar with Optimisation problems', 'Familiar with Optimisation methods', 
                        
                        'Solve tasks by myself', 'Trust automated methods', 'double check automated methods']

rate_skill = ['Basic', 'Limited',"Intermediate",'Proficient']
agreement = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']

options = [rate_skill]*3 + [agreement]*6 + [agreement]*3

questions = [
                {"column_name": "Numeracy", "options": rate_skill, "full_text": "$\\bf{Numeracy}$ skills"},
                {"column_name": "Problem solving", "options": rate_skill, "full_text": "$\\bf{Problem\ Solving}$ Skills"},
                {"column_name": "Algorithmic thinking", "options": rate_skill, "full_text": "$\\bf{Algorithmic\ Thinking}$"},
  
                {"column_name": "Confident in using technology", "options": agreement, "full_text": "I am $\\bf{confident}$ in using most technology"},
                {"column_name": "Technology is useful", "options": agreement, "full_text": "I $\\bf{trust}$ technology to produce useful results"},
                {"column_name": "Technology is overrated", "options": agreement, "full_text": "I think the usefulness of technology is $\\bf{overrated}$"},
                {"column_name": "Let technology decide for me", "options": agreement, "full_text": "I would trust technology \nto $\\bf{decide\ my\ work\ rota}$"},
                {"column_name": "Let technology decide my career", "options": agreement, "full_text": "I would trust technology to decide\n $\\bf{whether\ I'm\ suitable\ for\ a\ job}$"},
                {"column_name": "Let technology diagnose me", "options": agreement, "full_text": "I would trust technology \nto $\\bf{diagnose\ me}$ with serious diseases"},
  
                {"column_name": "Solve tasks by myself", "options": agreement, "full_text": "I prefer to $\\bf{solve\ tasks\ manually}$"},
                {"column_name": "Trust automated methods", "options": agreement, "full_text": "I trust that automated methods\n will produce the results I need"},
                {"column_name": "double check automated methods", "options": agreement, "full_text": "I $\\bf{double\ check}$ the results\n produced by automated methods"},
             ]

assert(len(subjective_questions) == len(options))
import matplotlib.pyplot as plt

def plot_histograms(df, question_data):
    num_plots = len(question_data)
    rows, cols = 3, 4
    fig, axes = plt.subplots(rows, cols, figsize=(16, 8))
    axes = axes.flatten()
    
    colors = plt.cm.get_cmap("tab20", num_plots)
    
    for idx, question in enumerate(question_data):
        col = question["column_name"]
        opt = question["options"]
        opt_without_newlines = [" ".join(original.split("\n")) for original in opt]
        title = question["full_text"]
        
        if col in df.columns:
            ax = axes[idx]
            data = df[col].dropna()
            
            if opt:
                data = pd.Categorical(data, categories=opt_without_newlines, ordered=True)
                data = data.value_counts().reindex(opt_without_newlines, fill_value=0)
                ax.bar(["\n".join(n.split()) for n in data.index], data.values, color=colors(idx+1), edgecolor='black', alpha=0.7)
            else:
                ax.hist(data, bins=20, color=colors(idx), edgecolor='black', alpha=0.7)
            
            ax.set_title(title)
            #ax.set_xlabel(col)
            ax.set_ylabel('Frequency')
            ax.grid(axis='y', alpha=0.75)
        else:
            print(f"Column '{col}' not found in DataFrame.")
    
    # Hide any unused subplots
    for i in range(num_plots, rows * cols):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.savefig(os.path.join(r"C:\Users\gac8\PycharmProjects\PS-descriptors-LCS\UserStudy", "subjective_info.pdf"))
    plt.show()
    
            
plot_histograms(get_all_data(exclude_bad_users=True), questions)
# Out:
# C:\Users\gac8\AppData\Local\Temp\ipykernel_21936\1408603861.py:45: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab20", num_plots)
